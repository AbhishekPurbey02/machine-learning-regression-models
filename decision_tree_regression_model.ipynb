# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
#Training the Decision tree model
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# predicting the decision tree model results
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %%
# Visualsing the Decision Tree model results
plt.scatter(x,y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.title('Truth or Bluff (Decision tree Regression)')
plt.xlabel('Postion Level')
plt.ylabel('Salary')
plt.show()

# %%
# Visualsing the decision tree model results for the higher resolutions
x_grid = np.arange(min(x), max(x), 0.01)
x_grid = x_grid.reshape((len(x_grid), 1))
plt.scatter(x,y, color = 'red')
plt.plot(x_grid, regressor.predict(x_grid), color = 'blue')
plt.title('Truth or Bluff (Decision tree Regression)')
plt.xlabel('Postion Level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\abhii\AppData\Local\Temp\ipykernel_5844\70046504.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.01)
